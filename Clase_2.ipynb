# %% [markdown]
# <a href="https://colab.research.google.com/github/Mily1702/mathUCE/blob/main/Clase_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Algoritmos y Sistemas Numéricos
# Un algoritmo es una secuencia de pasos definidos y ordenados que resuelven un problema o realizan una tarea específica. En programación, los algoritmos son esenciales para desarrollar soluciones eficientes y efectivas.
#
# ##Estructura EPS (Entrada-Proceso-Salida)
# La estructura EPS es una manera simple y clara de entender y diseñar algoritmos. Se compone de tres partes:
#
# 1.Entrada: Datos o información que el algoritmo recibe.
#
# 2.Proceso: Serie de pasos o instrucciones que transforman la entrada en salida.
#
# 3.Salida: Resultado final del proceso.
# #Ejemplo de EPS
# Supongamos que queremos sumar dos números:
#
# Entrada: Dos números,
# 𝑎
# a y
# 𝑏
# b.
#
# Proceso: Sumar
# 𝑎
# a y
# 𝑏
# b.
#
# Salida: El resultado de la suma.
#
# Pseudocódigo:
#
# Entrada: a, b
#
# Proceso: suma = a + b
#
# Salida: suma
#
# #Búsqueda Lineal
# La búsqueda lineal es un algoritmo sencillo utilizado para encontrar un elemento en una lista. Recorre la lista desde el principio hasta el final, comparando cada elemento con el valor buscado.
#
# #Ejemplo de Búsqueda Lineal
# Supongamos que tenemos una lista
# [
# 3
# ,
# 5
# ,
# 2
# ,
# 4
# ,
# 9
# ]
# [3,5,2,4,9] y queremos buscar el número 4.
#
# Pseudocódigo:
#
# Entrada: lista, valor_buscado
#
# Proceso:
#
#     Para cada elemento en la lista:
#
#         Si elemento == valor_buscado:
#
#             retornar índice del elemento
#
#     retornar -1 (si el valor_buscado no está en la lista)
#
# Salida: índice del valor_buscado o -1
#
# #Código en Python:
#
# def busqueda_lineal(lista, valor_buscado):
#
#     for i in range(len(lista)):
#
#         if lista[i] == valor_buscado:
#
#             return i
#
#     return -1
#
# # Ejemplo de uso
# lista = [3, 5, 2, 4, 9]
#
# valor_buscado = 4
#
# resultado = busqueda_lineal(lista, valor_buscado)
#
# print(f"El valor {valor_buscado} está en el índice {resultado}")
#
# #Búsqueda Binaria
# La búsqueda binaria es un algoritmo más eficiente que la búsqueda lineal, pero requiere que la lista esté ordenada. Divide la lista en dos partes y compara el valor buscado con el elemento central. Si no lo encuentra, descarta la mitad donde no podría estar y repite el proceso con la otra mitad.
#
# #Ejemplo de Búsqueda Binaria
# Supongamos que tenemos una lista ordenada
#
# [1,2,3,4,5,6,7,8,9] y queremos buscar el número 6.
#
# Pseudocódigo:
#
# Entrada: lista, valor_buscado
#
# Proceso:
#     establecer inicio = 0 y fin = longitud de la lista - 1
#
#     Mientras inicio <= fin:
#
#         calcular medio = (inicio + fin) / 2
#
#         Si lista[medio] == valor_buscado:
#
#             retornar medio
#
#         Si lista[medio] < valor_buscado:
#
#             inicio = medio + 1
#
#         Sino:
#
#             fin = medio - 1
#
#     retornar -1 (si el valor_buscado no está en la lista)
#
# Salida: índice del valor_buscado o -1
#
# #Código en Python:
#
# def busqueda_binaria(lista, valor_buscado):
#
#     inicio = 0
#     fin = len(lista) - 1
#
#     while inicio <= fin:
#         medio = (inicio + fin) // 2
#         if lista[medio] == valor_buscado:
#             return medio
#         elif lista[medio] < valor_buscado:
#             inicio = medio + 1
#         else:
#             fin = medio - 1
#     return -1
#
# # Ejemplo de uso
#
# lista = [1, 2, 3, 4, 5, 6, 7, 8, 9]
#
# valor_buscado = 6
#
# resultado = busqueda_binaria(lista, valor_buscado)
#
# print(f"El valor {valor_buscado} está en el índice {resultado}")
#
# #Herramientas y su función
# ![images.jpeg](data:image/jpeg;base64,...)
