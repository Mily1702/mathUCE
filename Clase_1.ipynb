# %% [markdown]
# <a href="https://colab.research.google.com/github/Mily1702/mathUCE/blob/main/Clase_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Fundamentos de Lógica y Conjuntos
# ##
# Lógica clásica que estudia las variables proposicionales, sus posibles implicaciones, los valores de verdad de las proposiciones o de conjuntos de ellas formadas a partir de los conectores lógicos.
# ##Conectores
# ![descarga.png](data:image/png;base64,...)
# ##Cuantificadores
# ![Cuantificadores.jpg](data:image/jpeg;base64,...)
# ##Reglas
# ![reglas.jpg](data:image/jpeg;base64,...)
# ## 2. Conjuntos
# Un conjunto es una familia de elementos considerada en sí misma como un objeto matemático.
# Los conjuntos pueden definirse citando todos los elementos de los que consta entre llaves,
# A={1,2,3,4,5}
# #Elemento:
# Cada objeto en un conjunto se llama elemento o miembro del conjunto. Si
# 𝑎
# a es un elemento del conjunto
# 𝐴
# A, se escribe
# 𝑎
# ∈
# 𝐴
# a∈A.
# #Conjunto vacío:
# Un conjunto que no tiene elementos se llama conjunto vacío y se denota por
# ∅
# ∅ o
# {
# }
# {}.
# #Subconjunto:
# Un conjunto
# 𝐴
# A es un subconjunto de
# 𝐵
# B si todos los elementos de
# 𝐴
# A están también en
# 𝐵
# B. Se escribe
# 𝐴
# ⊆
# 𝐵
# A⊆B.
# #Igualdad de conjuntos:
# Dos conjuntos
# 𝐴
# A y
# 𝐵
# B son iguales si tienen exactamente los mismos elementos, es decir,
# 𝐴
# =
# 𝐵
# A=B si y solo si
# 𝐴
# ⊆
# 𝐵
# A⊆B y
# 𝐵
# ⊆
# 𝐴
# B⊆A.
# #Operaciones con Conjuntos
# ##Unión
# (
# ∪
# ∪): La unión de dos conjuntos
# 𝐴
# A y
# 𝐵
# B es el conjunto de elementos que están en
# 𝐴
# A, en
# 𝐵
# B, o en ambos.
#
# 𝐴
# ∪
# 𝐵
# =
# {
# 𝑥
# :
# 𝑥
# ∈
# 𝐴
#  o
# 𝑥
# ∈
# 𝐵
# }
# A∪B={x:x∈A o x∈B}
# #Intersección
# (
# ∩
# ∩): La intersección de dos conjuntos
# 𝐴
# A y
# 𝐵
# B es el conjunto de elementos que están en ambos conjuntos.
#
# 𝐴
# ∩
# 𝐵
# =
# {
# 𝑥
# :
# 𝑥
# ∈
# 𝐴
#  y
# 𝑥
# ∈
# 𝐵
# }
# A∩B={x:x∈A y x∈B}
# #Diferencia
# (
# ∖
# ∖): La diferencia de dos conjuntos
# 𝐴
# A y
# 𝐵
# B es el conjunto de elementos que están en
# 𝐴
# A pero no en
# 𝐵
# B.
#
# 𝐴
# ∖
# 𝐵
# =
# {
# 𝑥
# :
# 𝑥
# ∈
# 𝐴
#  y
# 𝑥
# ∉
# 𝐵
# }
# A∖B={x:x∈A y x∈
# /
# B}
# #Complemento:
# El complemento de un conjunto
# 𝐴
# A en un universo
# 𝑈
# U es el conjunto de elementos que no están en
# 𝐴
# A.
#
# 𝐴
# 𝑐
# =
# {
# 𝑥
# :
# 𝑥
# ∈
# 𝑈
#  y
# 𝑥
# ∉
# 𝐴
# }
# A
# c
#  ={x:x∈U y x∈
# /
# A}
# #Ejemplo
# Consideremos los conjuntos:
#
# 𝐴
# =
# {
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# }
# A={1,2,3,4}
#
# 𝐵
# =
# {
# 3
# ,
# 4
# ,
# 5
# ,
# 6
# }
# B={3,4,5,6}
#
# Unión:
#
# 𝐴
# ∪
# 𝐵
# =
# {
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# ,
# 5
# ,
# 6
# }
# A∪B={1,2,3,4,5,6}
#
# Intersección:
#
# 𝐴
# ∩
# 𝐵
# =
# {
# 3
# ,
# 4
# }
# A∩B={3,4}
#
# Diferencia:
#
# 𝐴
# ∖
# 𝐵
# =
# {
# 1
# ,
# 2
# }
# A∖B={1,2}
#
# 𝐵
# ∖
# 𝐴
# =
# {
# 5
# ,
# 6
# }
# B∖A={5,6}
#
# Complemento (si asumimos el universo
# 𝑈
# =
# {
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# ,
# 5
# ,
# 6
# ,
# 7
# ,
# 8
# }
# U={1,2,3,4,5,6,7,8}):
#
# 𝐴
# 𝑐
# =
# {
# 5
# ,
# 6
# ,
# 7
# ,
# 8
# }
# A
# c
#  ={5,6,7,8}
#
# 𝐵
# 𝑐
# =
# {
# 1
# ,
# 2
# ,
# 7
# ,
# 8
# }
# B
# c
#  ={1,2,7,8}
# #Conjunto Universal (Ω)
# El conjunto universal, denotado como
# Ω, es el conjunto que contiene todos los objetos bajo consideración en un contexto particular. Por ejemplo, en un estudio sobre números naturales,
# Ω podría ser el conjunto de todos los números naturales
# 𝑁
# N. En teoría de la probabilidad,
# Ω se llama espacio muestral y contiene todos los posibles resultados de un experimento aleatorio.
#
# #Subconjuntos de
# #Ω
# Ω
# Cualquier conjunto
# 𝐴
# dentro del universo
# Ω
# es un subconjunto de
# Ω. Si
# Ω
# es el conjunto universal, todos los conjuntos bajo consideración son subconjuntos de
# Ω.
