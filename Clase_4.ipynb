# %% [markdown]
# <a href="https://colab.research.google.com/github/Mily1702/mathUCE/blob/main/Clase_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Funciones Matemáticas: Imagen y Preimagen
# #Funciones Matemáticas
# Una función matemática es una relación entre dos conjuntos de números, donde cada elemento del primer conjunto (dominio) se asigna a exactamente un elemento del segundo conjunto (codominio). Se denota como
# 𝑓
# :
# 𝐴
# →
# 𝐵
# f:A→B, donde
# 𝐴
# A es el dominio y
# 𝐵
# B es el codominio.
#
# Ejemplo:
# 𝑓
# (
# 𝑥
# )
# =
# 2
# 𝑥
# +
# 1
#
#
# Dominio
#
# A: Todos los números reales
#
# R.
#
# Codominio
#
# B: Todos los números reales
#
# R.
# #Concepto de Imagen y Preimagen
# Imagen: Es el conjunto de todos los valores posibles de la función
# 𝑓
# (
# 𝑥
# )
# f(x) cuando
# 𝑥
# x recorre el dominio
# 𝐴
# A. Se denota como
# 𝑓
# (
# 𝐴
# )
# f(A).
#
# #Ejemplo:
# Para
# 𝑓
# (
# 𝑥
# )
# =
# 𝑥
# 2
# f(x)=x
# 2
#  :
#
# Si
# 𝐴
# =
# {
# 1
# ,
# 2
# ,
# 3
# }
# A={1,2,3}, entonces
# 𝑓
# (
# 𝐴
# )
# =
# {
# 1
# ,
# 4
# ,
# 9
# }
# f(A)={1,4,9}.
# #Preimagen: Es el conjunto de todos los valores en el dominio
# 𝐴
# A que se asignan a un valor particular en el codominio
# 𝐵
# B. Se denota como
# 𝑓
# −
# 1
# (
# 𝑦
# )
# f
# −1
#  (y).
#
# Ejemplo: Para
# 𝑓
# (
# 𝑥
# )
# =
# 𝑥
# 2
# f(x)=x
# 2
#  :
#
# Si
# 𝑦
# =
# 4
# y=4, entonces
# 𝑓
# −
# 1
# (
# 4
# )
# =
# {
# −
# 2
# ,
# 2
# }
# f
# −1
#  (4)={−2,2} (porque
# 𝑓
# (
# −
# 2
# )
# =
# 4
# f(−2)=4 y
# 𝑓
# (
# 2
# )
# =
# 4
# f(2)=4).
# #Principios Básicos de Demostraciones Matemáticas
# Las demostraciones matemáticas son argumentos lógicos que establecen la verdad de una afirmación matemática. Utilizan reglas de inferencia y razonamiento deductivo para llegar a conclusiones válidas.
#
# #Principios Clave:
# Directa: Se parte de premisas verdaderas para llegar a una conclusión.
#
# Ejemplo: Demostrar que si
# 𝑎
# a y
# 𝑏
# b son números pares, entonces
# 𝑎
# +
# 𝑏
# a+b también es par.
#
# 𝑎
# =
# 2
# 𝑚
# a=2m y
# 𝑏
# =
# 2
# 𝑛
# b=2n para algunos enteros
# 𝑚
# m y
# 𝑛
# n.
# 𝑎
# +
# 𝑏
# =
# 2
# 𝑚
# +
# 2
# 𝑛
# =
# 2
# (
# 𝑚
# +
# 𝑛
# )
# a+b=2m+2n=2(m+n), que es par.
#
# Por Contradicción (Reductio ad Absurdum): Se asume lo contrario de lo que se quiere demostrar y se muestra que lleva a una contradicción.
#
# #Ejemplo:
# Demostrar que
# 2
# ​
#   es irracional.
#
# Supongamos que
# 2
#
# ​
#   es racional, entonces
# 2
# =
# 𝑝
# 𝑞
# 2
# ​
#  =
# q
# p
# ​
#   donde
# 𝑝
# p y
# 𝑞
# q son enteros coprimos.
# 2
# =
# 𝑝
# 𝑞
# ⇒
# 2
# =
# 𝑝
# 2
# 𝑞
# 2
# ⇒
# 𝑝
# 2
# =
# 2
# 𝑞
# 2
# 2
# ​
#  =
# q
# p
# ​
#  ⇒2=
# q
# 2
#
# p
# 2
#
# ​
#  ⇒p
# 2
#  =2q
# 2
#  .
# Esto implica que
# 𝑝
# 2
# p
# 2
#   es par, por lo tanto
# 𝑝
# p es par.
# Si
# 𝑝
# p es par, entonces
# 𝑝
# 2
# p
# 2
#   es divisible por 4.
# 𝑞
# 2
# =
# 𝑝
# 2
# 2
# q
# 2
#  =
# 2
# p
# 2
#
# ​
#   entonces
# 𝑞
# 2
# q
# 2
#   es par, y por lo tanto,
# 𝑞
# q es par.
# Esto contradice el hecho de que
# 𝑝
# p y
# 𝑞
# q no son enteros.
